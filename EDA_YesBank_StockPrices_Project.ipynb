# %% [markdown]
# # **Yes Bank Stock Closing Price Prediction**    -  **EDA**

# %% [markdown]
# ##### **Project Type**    - Exploratory Data Analysis (EDA) / Regression
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Solo Contribution
# ##### **Author Name -** Janani M

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Yes Bank is one of India's prominent private sector banks, well known in the financial markets ever since the fraud case involving its founder, Rana Kapoor, came to light in 2018. This case triggered a sharp and sustained decline in the bank's stock price, which had until then been on a strong upward trajectory since the bank's listing in 2005.
#
# This project focuses on the exploratory data analysis (EDA) of the monthly stock price data of Yes Bank, covering the period from July 2005 to November 2020. The dataset contains four key attributes for each month — Open, High, Low, and Close prices — with Close price being the eventual target for prediction in the follow-up Machine Learning notebook.
#
# The primary goal of this EDA notebook is to understand the underlying structure, trends, and relationships within the stock price data before any predictive modelling is attempted. Since the dataset is a monthly time series, the analysis pays close attention not only to the statistical relationships between the Open, High, Low, and Close columns, but also to how the stock behaved over time — including its steady rise through 2005-2018, the sharp crash following the governance/fraud crisis in 2018, and the further decline during the RBI-led reconstruction and the COVID-19 market crash in March 2020.
#
# The notebook begins with a structured "Know Your Data" section covering dataset shape, data types, duplicate values, and missing values — the dataset turned out to be extremely clean, with 185 monthly records and zero missing or duplicate entries. This is followed by an "Understanding Your Variables" section, which examines the statistical distribution and number of unique values of each column.
#
# The core of the notebook is the "Data Visualization, Storytelling & Experimenting with Charts" section, which follows the UBM approach (Univariate, Bivariate, Multivariate analysis). A total of 20 charts have been created, ranging from simple distribution plots of the Close price, to time series line plots that visually capture the 2018 stock crash, to bivariate scatter plots between Open/High/Low and Close, to a year-wise and month-wise average price analysis, a rolling volatility analysis, a correlation heatmap, and a pair plot. For every chart, the notebook explains why that specific chart was chosen, what insight it reveals, and whether that insight could help or hurt a business/investment decision — as required by the assignment guidelines.
#
# Key findings from the analysis include: an extremely high correlation (above 0.97) between Open, High, Low and Close prices, which strongly suggests that a simple regression-based model should be able to predict the Close price with high accuracy; a dramatic price peak of about ₹367.90 in July 2018 followed by a crash to single/double digits by 2020; and clear evidence that monthly volatility (the High-Low spread) increased sharply during the crisis period, which is a classic signature of panic-driven trading.
#
# The notebook closes with a "Solution to Business Objective" section that translates these findings into actionable suggestions for the bank/investors — such as using the Open-High-Low relationship for near-term price estimation, and treating periods of widening High-Low spread as an early warning signal of instability — followed by an overall conclusion. Together, this EDA lays the complete analytical foundation for the Machine Learning regression model built in the companion ML notebook.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# [https://github.com/Janani23092/YES-BANK-STOCK-PRICE-PREDICTION](https://github.com/Janani23092/YES-BANK-STOCK-PRICE-PREDICTION)

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Yes Bank is a major Indian bank that has been in the news since 2018 because of a fraud case involving its former CEO, Rana Kapoor. This case, combined with a deterioration in asset quality, caused a very sharp decline in Yes Bank's stock price. Given the monthly stock price data (Open, High, Low, Close) of Yes Bank from July 2005 to November 2020, the objective of this notebook is to explore, visualize, and understand the data thoroughly — the overall trend, the impact of the 2018-19 crisis, and the relationships between the four price columns — so that this understanding can be used to build a reliable model to predict the monthly closing price of the stock (Close) in the subsequent Machine Learning notebook.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective is to explore and understand the historical stock price behaviour of Yes Bank well enough to (a) identify the key drivers of the closing price, (b) understand and quantify the effect of the 2018 fraud/governance crisis on the stock, and (c) prepare a clean, well-understood dataset that can support an accurate Close-price prediction model — which in turn can help investors, analysts, and the bank's own management make better-informed decisions.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#            [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                      without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 5)

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import files
import pandas as pd

uploaded = files.upload()

file_name = list(uploaded.keys())[0]

df = pd.read_csv(file_name)

print("Dataset loaded successfully!")
print("File name:", file_name)
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])

df.head()
# Out:
#      <input type="file" id="files-681b5a50-c7a0-4ce6-a14e-a226a6231af6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-681b5a50-c7a0-4ce6-a14e-a226a6231af6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#      Date   Open   High    Low  Close
# 0  Jul-05  13.00  14.00  11.25  12.46
# 1  Aug-05  12.58  14.88  12.55  13.42
# 2  Sep-05  13.48  14.87  12.27  13.30
# 3  Oct-05  13.20  14.47  12.40  12.99
# 4  Nov-05  13.35  13.88  12.88  13.41

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(f"Number of Rows    : {df.shape[0]}")
print(f"Number of Columns : {df.shape[1]}")
# Out:
# Number of Rows    : 185
# Number of Columns : 5

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    185 non-null    object
#  1   Open    185 non-null    float64
#  2   High    185 non-null    float64
#  3   Low     185 non-null    float64
#  4   Close   185 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 7.4+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_count = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# Date     0
# Open     0
# High     0
# Low      0
# Close    0
# dtype: int64

# %%
# Visualizing the missing values
plt.figure(figsize=(10, 4))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis', yticklabels=False)
plt.title('Missing Value Heatmap (no missing values expected)')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset contains **185 monthly records** of Yes Bank's stock price from **July 2005 to November 2020**, with **5 columns**: `Date` (month-year), `Open`, `High`, `Low`, and `Close` price. There are **no missing values and no duplicate rows** — the data is already very clean. All four price columns are numeric (`float64`), while `Date` is currently stored as a string/object and will need to be converted to a proper datetime type during data wrangling. The Close price ranges from as low as ₹9.98 (March 2009) to as high as ₹367.90 (July 2018), reflecting the huge swing the stock has gone through over its listed history.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close'], dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#              Open        High         Low       Close
# count  185.000000  185.000000  185.000000  185.000000
# mean   105.541405  116.104324   94.947838  105.204703
# std     98.879850  106.333497   91.219415   98.583153
# min     10.000000   11.240000    5.550000    9.980000
# 25%     33.800000   36.140000   28.510000   33.450000
# 50%     62.980000   72.550000   58.000000   62.540000
# 75%    153.000000  169.190000  138.350000  153.300000
# max    369.950000  404.000000  345.500000  367.900000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# - **Date** – The month and year of the record, in `Mon-YY` format (e.g. `Jul-05` = July 2005).
# - **Open** – The stock's opening price (₹) for that month.
# - **High** – The highest price (₹) the stock touched during that month.
# - **Low** – The lowest price (₹) the stock touched during that month.
# - **Close** – The stock's closing price (₹) at the end of that month — **this is the target variable** we want to predict in the ML notebook.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for col in df.columns:
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# Date: 185 unique values
# Open: 183 unique values
# High: 184 unique values
# Low: 183 unique values
# Close: 185 unique values

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# Convert the 'Date' column (e.g. 'Jul-05') into a proper datetime object
df['Date'] = pd.to_datetime(df['Date'], format='%b-%y')

# Sort chronologically (data should already be sorted, but this guarantees it)
df = df.sort_values('Date').reset_index(drop=True)

# Extract Year and Month for later time-based analysis
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

# Engineer a couple of helpful analytical features
df['Monthly_Range'] = df['High'] - df['Low']          # intra-month volatility
df['Pct_Change'] = df['Close'].pct_change() * 100       # month-over-month % change in Close

df.head()
# Out:
#         Date   Open   High    Low  Close  Year  Month  Monthly_Range  \
# 0 2005-07-01  13.00  14.00  11.25  12.46  2005      7           2.75
# 1 2005-08-01  12.58  14.88  12.55  13.42  2005      8           2.33
# 2 2005-09-01  13.48  14.87  12.27  13.30  2005      9           2.60
# 3 2005-10-01  13.20  14.47  12.40  12.99  2005     10           2.07
# 4 2005-11-01  13.35  13.88  12.88  13.41  2005     11           1.00
#
#    Pct_Change
# 0         NaN
# 1    7.704655
# 2   -0.894188
# 3   -2.330827
# 4    3.233256

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# The `Date` column was converted from a text string (e.g. `Jul-05`) into a proper `datetime` object, and the data was sorted chronologically. Two new features were engineered directly from the raw OHLC columns: **`Monthly_Range`** (`High - Low`), which captures how volatile the stock was within a given month, and **`Pct_Change`**, the month-over-month percentage change in the closing price. `Year` and `Month` were also extracted from `Date` to make yearly/seasonal comparisons possible. These derived columns turned out to be extremely useful — the `Monthly_Range` spikes dramatically during 2018-2020, visually confirming the increased volatility during the fraud-crisis and COVID-19 periods, while `Pct_Change` highlights the exact months of the sharpest single-month crashes.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
plt.figure(figsize=(8, 5))
sns.histplot(df['Close'], kde=True, color='teal', bins=25)
plt.title('Distribution of Monthly Closing Price')
plt.xlabel('Close Price (₹)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram with a KDE overlay is the standard first chart for understanding the distribution of a continuous numeric target variable like Close price.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The distribution is heavily right-skewed — most months the Close price stayed under ₹100, with a long tail stretching up to ~₹368. This tells us the stock spent a large portion of its listed life at low-to-moderate price levels, with a comparatively short period at very high prices (2017-2018).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this is useful — it flags that any regression model will need to deal with a skewed target, and that a few very high-value months (2018 peak) could act as high-leverage points. There's no negative growth implication by itself; it's descriptive.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.figure(figsize=(8, 5))
sns.histplot(df['Open'], kde=True, color='steelblue', bins=25)
plt.title('Distribution of Monthly Opening Price')
plt.xlabel('Open Price (₹)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Comparing the distribution of Open against Close (Chart 1) helps confirm whether the two behave similarly, which is expected since they are related prices within the same month.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Open price distribution is almost identical in shape to the Close price distribution — right-skewed with the bulk of values below ₹100. This is expected because a stock's opening and closing price rarely diverge hugely within a single month.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This confirms Open is a strong, safe candidate feature for predicting Close, since their marginal distributions are so similar. No negative-growth insight here — it's purely confirmatory.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
plt.figure(figsize=(8, 4))
sns.boxplot(x=df['Close'], color='orange')
plt.title('Boxplot of Closing Price (Outlier Check)')
plt.xlabel('Close Price (₹)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A boxplot is the standard way to spot outliers and understand the spread (IQR, median) of a numeric variable in a single, compact chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The boxplot shows several points beyond the upper whisker, corresponding to the 2017-2018 boom period when the stock traded well above ₹200. Statistically, these look like outliers, but in reality they represent a genuine, real market regime rather than a data error.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This is an important insight for modelling: these 'outliers' should NOT be removed, since they are real, legitimate price levels. Removing them would make the model blind to how the stock behaves in a bull-run, which would hurt prediction quality during any future rally — a case where blindly 'cleaning' outliers would cause negative impact.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.figure(figsize=(8, 5))
sns.histplot(df['Monthly_Range'], kde=True, color='crimson', bins=25)
plt.title('Distribution of Monthly Volatility (High - Low)')
plt.xlabel('Monthly Range (₹)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart visualizes the engineered `Monthly_Range` feature, which is a proxy for intra-month volatility — an important angle beyond just price level.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most months have a fairly small High-Low spread (under ₹20), but there's a long right tail — a handful of months had swings of ₹80-100+. These extreme-volatility months line up almost exactly with the 2018 crisis and the March 2020 COVID crash.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — flagging high-volatility months can help risk teams and investors set wider stop-losses or expect larger price swings during crisis periods, which is a genuinely useful early-warning signal rather than a negative-growth insight.

# %% [markdown]
# #### Chart - 5 - Closing Price Trend Over Time

# %%
# Chart - 5 visualization code
plt.figure(figsize=(12, 5))
plt.plot(df['Date'], df['Close'], color='darkblue', linewidth=1.5)
plt.title('Yes Bank Monthly Closing Price (2005 - 2020)')
plt.xlabel('Date')
plt.ylabel('Close Price (₹)')
plt.axvline(pd.Timestamp('2018-07-01'), color='red', linestyle='--', alpha=0.7, label='Jul-2018 peak (₹367.9)')
plt.axvline(pd.Timestamp('2020-03-01'), color='black', linestyle='--', alpha=0.7, label='Mar-2020 (RBI moratorium / COVID crash)')
plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A time-series line plot is the single most important chart for this dataset — it directly shows the trend, and this is a stock-price prediction problem where the temporal pattern matters more than anything else.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart clearly shows three distinct phases: (1) a slow, steady climb from 2005 to 2016, (2) an explosive rally through 2017 into a peak of ₹367.90 in July 2018, and (3) a dramatic, sustained crash from late 2018 through 2020 — driven first by the Rana Kapoor fraud/NPA disclosure crisis and then compounded by the RBI-led reconstruction and moratorium in March 2020 alongside the broader COVID-19 market crash — bringing the stock down to single-digit/low-double-digit levels by late 2020.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This is the single most business-critical insight in the whole notebook: it shows that Yes Bank's price collapse was driven by a specific governance/fraud event, not gradual market forces. For an ML model, it means recent months carry a completely different price regime than the historical average, which has to be accounted for (e.g. through time-aware train/test splitting) — ignoring this would clearly lead to a misleading, overly optimistic model and poor real-world predictions (negative business impact if not handled).

# %% [markdown]
# #### Chart - 6 - Open, High, Low, Close Together

# %%
# Chart - 6 visualization code
plt.figure(figsize=(12, 5))
plt.plot(df['Date'], df['Open'], label='Open', alpha=0.8)
plt.plot(df['Date'], df['High'], label='High', alpha=0.8)
plt.plot(df['Date'], df['Low'], label='Low', alpha=0.8)
plt.plot(df['Date'], df['Close'], label='Close', linewidth=2, color='black')
plt.title('Open, High, Low, Close Over Time')
plt.xlabel('Date')
plt.ylabel('Price (₹)')
plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Plotting all four OHLC series together on the same time axis is a natural multivariate extension of Chart 5, useful for seeing how tightly the four prices move together.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# All four lines move almost perfectly in lock-step throughout the entire history, including through the crash. The gap between High and Low visibly widens only during the most volatile 2018-2020 period, otherwise the four series are nearly indistinguishable.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — this visually confirms that Open, High, and Low will be extremely strong predictors of Close, since they co-move almost identically. This is a positive signal for building a simple, reliable regression model.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
plt.figure(figsize=(7, 6))
sns.scatterplot(x='Open', y='Close', data=df, color='purple', alpha=0.7)
plt.title('Open Price vs Close Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is the right chart to examine the numerical-numerical relationship between the Open price and the target Close price, which is important since Open will likely be a key model feature.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The points line up almost perfectly along a straight diagonal line, confirming an extremely strong positive linear relationship between Open and Close (correlation of about 0.98).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — a near-perfect linear relationship like this is great news for a regression-based ML approach: a simple linear model using Open as a feature should already explain most of the variance in Close price.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
plt.figure(figsize=(7, 6))
sns.scatterplot(x='High', y='Close', data=df, color='green', alpha=0.7)
plt.title('High Price vs Close Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Similarly to Chart 7, this scatter examines the relationship between the monthly High price and Close price.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# High shows the strongest linear relationship with Close of all three predictors (correlation ~0.985), with points tightly hugging the diagonal even at the highest price levels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — High is likely to be the single most important predictor for the ML model given this very tight relationship, which is a positive finding for the modelling stage.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
plt.figure(figsize=(7, 6))
sns.scatterplot(x='Low', y='Close', data=df, color='darkorange', alpha=0.7)
plt.title('Low Price vs Close Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Completing the trio of numerical-numerical bivariate comparisons started in Charts 7 and 8, this scatter checks Low against Close.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Low has the highest correlation with Close of all three OHLC predictors (~0.995) and the tightest-looking scatter of the three, meaning knowing just the month's Low price alone gives an excellent estimate of where it closed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — this is a strong, positive insight for feature selection in the ML notebook: all three of Open, High, Low individually carry very strong predictive signal for Close.

# %% [markdown]
# #### Chart - 10 - Average Closing Price by Year

# %%
# Chart - 10 visualization code
yearly_avg = df.groupby('Year')['Close'].mean()
plt.figure(figsize=(11, 5))
yearly_avg.plot(kind='bar', color='slateblue')
plt.title('Average Yearly Closing Price')
plt.xlabel('Year')
plt.ylabel('Average Close Price (₹)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is the natural choice to compare a numerical variable (average Close) across a categorical/ordinal variable (Year) — this is a Numerical-Categorical bivariate analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar chart clearly shows a steady year-on-year rise from 2005 through 2017, a huge spike in 2018 (the year of both the peak and the crash), and then a steep decline in 2019 and 2020 — condensing the entire story of Chart 5 into a single, easy-to-read yearly summary.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — this year-level view is very useful for high-level reporting to stakeholders/investors who want an at-a-glance summary rather than a detailed monthly trend. The sharp 2019-2020 decline is a clear negative-growth signal, directly justified by the fraud case and subsequent RBI moratorium/reconstruction of the bank.

# %% [markdown]
# #### Chart - 11 - Average Closing Price by Calendar Month

# %%
# Chart - 11 visualization code
monthly_avg = df.groupby('Month')['Close'].mean()
plt.figure(figsize=(10, 5))
monthly_avg.plot(kind='bar', color='seagreen')
plt.title('Average Closing Price by Calendar Month (Seasonality Check)')
plt.xlabel('Month (1 = Jan, 12 = Dec)')
plt.ylabel('Average Close Price (₹)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This bar chart checks for any calendar-month seasonality by averaging Close price across all years for each calendar month — another Numerical-Categorical comparison, but for a different categorical grouping than Chart 10.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is no strong or consistent seasonal pattern — the averages across months 1-12 are fairly similar, with differences explained more by which years happened to include extreme highs/lows rather than any genuine month-of-year effect.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This is a useful negative finding: it tells us NOT to bother engineering calendar-month seasonal features for the ML model, since month-of-year has little independent explanatory power once the overall time trend is accounted for — saving effort that would otherwise not pay off.

# %% [markdown]
# #### Chart - 12 - 12-Month Rolling Average & Volatility

# %%
# Chart - 12 visualization code
df['Rolling_Mean_12'] = df['Close'].rolling(window=12).mean()
df['Rolling_Std_12'] = df['Close'].rolling(window=12).std()

fig, ax1 = plt.subplots(figsize=(12, 5))
ax1.plot(df['Date'], df['Close'], color='lightgray', label='Close')
ax1.plot(df['Date'], df['Rolling_Mean_12'], color='blue', label='12-Month Rolling Mean')
ax1.set_ylabel('Price (₹)')
ax1.legend(loc='upper left')

ax2 = ax1.twinx()
ax2.plot(df['Date'], df['Rolling_Std_12'], color='red', alpha=0.6, label='12-Month Rolling Std Dev')
ax2.set_ylabel('Rolling Std Dev (₹)')
ax2.legend(loc='upper right')

plt.title('Trend (Rolling Mean) vs Volatility (Rolling Std Dev)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A dual-axis rolling-statistics chart is a classic multivariate time-series visualization that layers the smoothed trend (rolling mean) together with a rolling measure of volatility (rolling std dev), giving a richer picture than the raw price line alone.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The rolling standard deviation stays low and flat for most of the stock's history, then rises sharply starting in 2018 and stays elevated through 2020 — meaning volatility, not just price level, increased dramatically during and after the crisis, and has not fully settled back down.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — persistently high volatility is itself a red flag for investors and risk managers, independent of price direction. It suggests the market still viewed Yes Bank as a higher-risk stock even after the initial crash, which is a genuine negative-growth-risk insight worth flagging in any investment analysis.

# %% [markdown]
# #### Chart - 13 - Month-over-Month % Change in Close Price

# %%
# Chart - 13 visualization code
plt.figure(figsize=(12, 5))
colors = ['green' if x > 0 else 'red' for x in df['Pct_Change'].fillna(0)]
plt.bar(df['Date'], df['Pct_Change'].fillna(0), color=colors, width=20)
plt.title('Month-over-Month % Change in Closing Price')
plt.xlabel('Date')
plt.ylabel('% Change')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A colored bar chart of month-over-month percentage change highlights the sharpest single-month gains and losses, which a simple price-level chart like Chart 5 can hide.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows several severe single-month crashes clustered in 2018-2020 (multiple months with 30-50%+ declines), far larger in magnitude and frequency than anything seen in the 2005-2017 period, confirming the crisis wasn't a single event but a series of repeated shocks.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This has a clear negative-growth story that needs to be told honestly to stakeholders: several of the sharpest single-month crashes directly followed news events (fraud disclosure, RBI action, reconstruction scheme, COVID-19 lockdown) — useful context for understanding why the ML model may find these specific months harder to predict accurately.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(6, 5))
corr = df[['Open', 'High', 'Low', 'Close']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.3f', square=True)
plt.title('Correlation Heatmap (OHLC)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap is the standard multivariate chart to summarize pairwise linear relationships between every numeric variable at once, which is essential before choosing features for the ML model.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# All four variables are extremely highly correlated with each other (all pairwise correlations above 0.97), with Low and Close being the most tightly related pair (~0.995). This confirms, in a single glance, the pattern already seen individually in Charts 7-9.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes — this is one of the most actionable insights in the notebook: since Open, High, and Low are all so strongly (and similarly) correlated with Close, a simple, interpretable regression model is likely to perform very well, and multicollinearity between the predictors themselves will need to be kept in mind during model selection (covered in the ML notebook).

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(df[['Open', 'High', 'Low', 'Close']], diag_kind='kde', corner=True)
plt.suptitle('Pair Plot of OHLC Variables', y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot gives, in one figure, every pairwise scatter plot plus each variable's individual distribution — the most complete multivariate visualization for a small set of numeric columns like this one.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Every scatter panel shows the same tight, near-linear diagonal relationship, and every diagonal (distribution) panel shows the same right-skew already seen in Charts 1-2. This confirms the dataset's core relationships are consistent and there are no hidden non-linear surprises between any pair of OHLC columns.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The strong and consistent relationships among Open, High, Low, and Close prices support the use of these variables in a regression-based machine learning model. This can help build a reliable closing-price estimation system. However, the model should be used as a decision-support tool rather than a guaranteed stock-market forecasting system.

# %% [markdown]
# #### Chart - 16 - Distribution of High Price

# %%
# Chart 16 - Distribution of High Price

plt.figure(figsize=(8, 5))

sns.histplot(
    data=df,
    x='High',
    bins=25,
    kde=True
)

plt.title('Distribution of Monthly High Price')
plt.xlabel('High Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram with a KDE curve was selected to understand the distribution, spread, and skewness of the monthly High price. Since High is one of the main independent variables used to predict Close, understanding its distribution is important before building the machine learning model.

# %% [markdown]
# #####2. What insight was found?

# %% [markdown]
# The High price distribution is strongly right-skewed. Most monthly High prices are concentrated at lower and moderate price levels, while a smaller number of observations extend to very high values. These high-value observations mainly belong to the strong growth period before the 2018 decline.

# %% [markdown]
# ##### 3. Will the gained insights help create a positive business impact?

# %% [markdown]
# Yes. The analysis confirms that High contains a wide range of genuine market values and is an important variable for predicting Close. The extreme values should not be removed automatically because they represent actual historical market conditions.

# %% [markdown]
# #### Chart 17 — Distribution of Low Price

# %%
# Chart - 17 visualization code

plt.figure(figsize=(8, 5))

sns.histplot(
    df['Low'],
    kde=True,
    bins=25,
    color='darkorange'
)

plt.title('Distribution of Monthly Low Price')
plt.xlabel('Low Price (₹)')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This histogram was selected to understand the distribution of the monthly Low price. Low is especially important because the previous correlation analysis showed that it has a very strong relationship with the target variable Close.

# %% [markdown]
# ##### 2. What insight was found?

# %% [markdown]
# The Low price also has a right-skewed distribution, similar to Open, High, and Close. Most observations occur at lower price levels, while fewer observations belong to the high-price period of the stock.

# %% [markdown]
# ##### 3. Will the gained insights help create a positive business impact?

# %% [markdown]
# Yes. The similarity between the Low and Close distributions supports the earlier finding that Low can be a strong predictor of Close. This is useful for selecting appropriate independent variables for the machine learning stage.

# %% [markdown]
# #### Chart 18 — Comparison of All OHLC Price Distributions

# %%
# Chart - 18 visualization code

plt.figure(figsize=(10, 6))

sns.boxplot(
    data=df[['Open', 'High', 'Low', 'Close']]
)

plt.title('Comparison of Open, High, Low and Close Price Distributions')
plt.xlabel('Stock Price Variables')
plt.ylabel('Price (₹)')

plt.show()

# %% [markdown]
# #####1. Why did you pick the specific chart?

# %% [markdown]
# A combined boxplot was selected to compare the median, spread, interquartile range, and extreme observations of all four stock-price variables in a single visualization.

# %% [markdown]
# ##### 2. What insight was found?

# %% [markdown]
# Open, High, Low, and Close have very similar distributions and spreads. High naturally reaches the largest values, while Low has comparatively smaller values. All four variables contain high-value statistical outliers that correspond to genuine historical market periods.

# %% [markdown]
# ##### 3. Will the gained insights help create a positive business impact?

# %% [markdown]
# Yes. This chart confirms that the four stock-price variables behave similarly and supports their strong relationship observed in the correlation analysis. It also confirms that extreme values should be retained rather than removed blindly.

# %% [markdown]
# #### Chart 19 — Monthly Price Range Over Time

# %%
# Chart - 19 visualization code

plt.figure(figsize=(12, 5))

plt.plot(
    df['Date'],
    df['Monthly_Range'],
    color='crimson',
    linewidth=1.5
)

plt.title('Monthly Price Range Over Time')
plt.xlabel('Date')
plt.ylabel('Monthly Range: High - Low (₹)')

plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A time-series line chart was selected because the Monthly_Range variable represents the difference between the monthly High and Low prices. Plotting it over time helps identify periods when the stock experienced unusually large price movements.

# %% [markdown]
# ##### 2. What insight was found?

# %% [markdown]
# For much of the historical period, the monthly High-Low range remained relatively moderate. However, several sharp spikes can be observed during periods of strong market movement and uncertainty. These spikes indicate that volatility was not constant throughout the stock's history.

# %% [markdown]
# ##### 3. Will the gained insights help create a positive business impact?

# %% [markdown]
# Yes. A sudden increase in the High-Low range can act as a simple risk-warning indicator. Investors and analysts can use widening price ranges to identify periods of increased uncertainty and review their risk-management decisions.

# %% [markdown]
# #### Chart 20 — Open-to-Close Percentage Change Over Time

# %%
# Chart - 20 visualization code

# Calculate percentage change from Open price to Close price
df['Open_Close_Change_Pct'] = (
    (df['Close'] - df['Open']) / df['Open']
) * 100

plt.figure(figsize=(12, 5))

plt.plot(
    df['Date'],
    df['Open_Close_Change_Pct'],
    color='purple',
    linewidth=1.2
)

plt.axhline(
    y=0,
    color='black',
    linestyle='--',
    alpha=0.7
)

plt.title('Open-to-Close Percentage Change Over Time')
plt.xlabel('Date')
plt.ylabel('Open-to-Close Change (%)')

plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart was selected to measure how much the stock's closing price changed relative to its opening price during each month. Unlike raw price charts, percentage change makes movements across different historical price levels easier to compare.

# %% [markdown]
# #####2. What insight was found?

# %% [markdown]
# The stock experienced both positive and negative open-to-close movements throughout the historical period. Some months show unusually large percentage changes, indicating periods of stronger market uncertainty and directional movement.

# %% [markdown]
# ##### 3. Will the gained insights help create a positive business impact?

# %% [markdown]
# Yes. Large positive or negative open-to-close percentage movements can help identify unusual market behaviour. This information can support risk monitoring and can also help explain periods where a machine learning model may produce larger prediction errors.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on this exploratory analysis, the following is suggested to Yes Bank / investors and analysts tracking the stock:
#
# 1. **Use Open, High, and Low as core predictive features** — their correlation with Close (all above 0.97) is strong enough that a simple, interpretable regression model can deliver highly accurate monthly Close-price predictions, without needing complex non-linear models.
# 2. **Treat the 2018 onward period as a structurally different regime.** Any predictive model or business decision based purely on the 2005-2017 trend would have been dangerously misleading once the fraud/governance crisis hit — models and dashboards should be re-validated whenever a major governance or regulatory event occurs.
# 3. **Monitor `Monthly_Range` (High − Low) as an early-warning volatility signal.** A sudden widening of this spread preceded and accompanied the worst of the crash, and could act as a simple, explainable risk flag for analysts in the future.
# 4. **Communicate risk transparently to investors.** The month-over-month % change analysis shows several severe single-month crashes; being upfront about this volatility (rather than only reporting long-run averages) supports better-informed, more risk-aware investment decisions.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This EDA has shown that Yes Bank's monthly stock price data is clean (no missing values, no duplicates) and tells a clear, coherent story: a decade-plus of steady growth (2005-2016), an explosive rally into a peak of ₹367.90 in July 2018, followed by a severe and sustained crash driven by the Rana Kapoor fraud/NPA disclosure, the RBI-led reconstruction and moratorium in March 2020, and the broader COVID-19 market downturn.
#
# Across 20 charts covering univariate, bivariate, and multivariate analysis, the single most important finding is the very strong linear relationship between Open, High, Low, and the target Close price (all pairwise correlations above 0.97) — this is excellent news for the Machine Learning stage, where a well-chosen regression model should be able to predict the monthly closing price with high accuracy. At the same time, the sharply increased volatility and structural break around 2018 highlights the importance of being careful about how the data is split for training and testing a predictive model, which is addressed in detail in the companion ML notebook.
